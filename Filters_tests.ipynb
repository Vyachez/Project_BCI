# %% [markdown]
# # Notch and Bandpass Filters test
# <i>November 6, 2018</i><br>
# Viacheslav Nesterov

# %%
# Imports
import sys
import os
import numpy as np
import pandas as pd

from imp import reload
import utils
reload(utils)
from utils import*

import matplotlib.pyplot as plt
# %matplotlib inline

# path
path = 'SavedData/'

# %% [markdown]
# ### Comparing different filter modes recorded from GUI

# %% [markdown]
# Sample rate = 1000 Hz, Latency = 10 ms

# %% [markdown]
# <b><i>Notch filter 60Hz BP 7-13</i></b>

# %%
# Notch filter 60Hz BP 7-13
n_60_bp_7_13 = pd.read_csv(path+'OpenBCI-RAW-test_BP_7-13.txt', sep=",", header=None)

# %%
n_60_bp_7_13[:3]
# Out:
#    0          1         2         3         4         5         6         7   \
# 0  20 -137333.81  14619.16 -52489.52 -67850.98 -17034.09 -19080.77 -28495.84
# 1  21 -137269.14  16624.09 -54596.01 -66375.16 -19914.53 -22100.98 -31318.23
# 2  22 -130904.75  18536.14 -58616.93 -61295.12 -25141.64 -27537.71 -36443.04
#
#          8    9    10   11             12
# 0 -12661.61  0.0  0.0  0.0   06:33:43.895
# 1 -12700.80  0.0  0.0  0.0   06:33:43.896
# 2 -14030.61  0.0  0.0  0.0   06:33:43.897

# %%
d_plot(n_60_bp_7_13)

# %% [markdown]
# <b><i>Notch filter 60Hz BP 5-50</i></b>

# %%
# Notch filter 60Hz BP 5-50
n_60_bp_5_50 = pd.read_csv(path+'OpenBCI-RAW-test_BP_5-50.txt', sep=",", header=None)

# %%
n_60_bp_5_50[:3]
# Out:
#    0         1        2         3         4         5         6         7   \
# 0   1  -4969.84 -3468.23 -62740.88 -56817.13 -35450.89 -25971.27 -55858.89
# 1   2   6815.20 -3292.48 -63933.05 -57855.34 -36586.56 -27374.54 -57400.82
# 2   3  18227.20 -3981.54 -65772.87 -59588.41 -38530.52 -28992.18 -59005.27
#
#         8    9    10   11             12
# 0  -606.43  0.0  0.0  0.0   06:36:01.123
# 1  1830.36  0.0  0.0  0.0   06:36:01.123
# 2  3968.35  0.0  0.0  0.0   06:36:01.123

# %%
d_plot(n_60_bp_5_50)

# %% [markdown]
# <b><i>Notch filter 60Hz BP 15-50</i></b>

# %%
# Notch filter 60Hz BP 15-50
n_60_bp_15_50 = pd.read_csv(path+'OpenBCI-RAW-test_BP_15-50.txt', sep=",", header=None)

# %%
n_60_bp_15_50[:3]
# Out:
#    0         1         2         3         4         5         6         7   \
# 0   1  44708.94 -12117.93 -64435.41 -56857.61 -39829.49 -27347.29 -63706.52
# 1   2  53028.24 -13297.52 -65075.89 -57494.09 -40318.95 -28101.37 -64484.78
# 2   3  54961.71 -14315.26 -64685.41 -57133.67 -39656.42 -27973.12 -64387.26
#
#         8    9    10   11             12
# 0 -1341.06  0.0  0.0  0.0   06:37:17.319
# 1 -1929.31  0.0  0.0  0.0   06:37:17.319
# 2 -3576.30  0.0  0.0  0.0   06:37:17.320

# %%
d_plot(n_60_bp_15_50)

# %% [markdown]
# <b><i>Notch filter 60Hz NO BP</i></b>

# %%
# Notch filter 60Hz No BP
n_60_bp_no = pd.read_csv(path+'OpenBCI-RAW-test_BP_NO.txt', sep=",", header=None)

# %%
n_60_bp_no[:3]
# Out:
#    0         1         2         3         4         5         6         7   \
# 0   1   5000.06 -12331.81 -58548.16 -50092.54 -34017.43 -21626.59 -56211.48
# 1   2  17184.87 -13491.71 -59997.87 -51483.26 -35502.68 -23043.02 -57638.42
# 2   3  28765.46 -14632.19 -61257.55 -52665.40 -36764.39 -24259.76 -58875.01
#
#         8    9    10   11             12
# 0 -5591.31  0.0  0.0  0.0   06:38:16.279
# 1 -4800.98  0.0  0.0  0.0   06:38:16.279
# 2 -4484.77  0.0  0.0  0.0   06:38:16.279

# %%
d_plot(n_60_bp_no)

# %% [markdown]
# <b><i>Notch NO BP 7-13</i></b>

# %%
# Notch NO BP 7-13
n_no_bp_7_13 = pd.read_csv(path+'OpenBCI-RAW-test_Notch_No_BP_7-13.txt', sep=",", header=None)

# %%
n_no_bp_7_13[:3]
# Out:
#    0         1         2         3         4         5         6         7   \
# 0   1  22796.86 -17225.80 -59430.14 -49093.39 -34040.27 -22524.16 -56118.90
# 1   2  13846.70 -17182.14 -58251.41 -47954.35 -32701.41 -21448.98 -55065.00
# 2   3   5750.41 -16731.44 -57249.66 -46961.26 -31635.07 -20425.58 -54049.06
#
#          8    9    10   11             12
# 0 -11925.97  0.0  0.0  0.0   06:39:23.360
# 1 -13165.22  0.0  0.0  0.0   06:39:23.360
# 2 -13771.02  0.0  0.0  0.0   06:39:23.360

# %%
d_plot(n_no_bp_7_13)

# %% [markdown]
# <b><i>Notch NO BP NO</i></b>

# %%
# Notch NO BP NO
n_no_bp_no = pd.read_csv(path+'OpenBCI-RAW-test_Notch_No_BP_No.txt', sep=",", header=None)

# %%
n_no_bp_no[:3]
# Out:
#    0         1         2          3         4        5        6         7   \
# 0   1  20172.52  46095.66 -104046.79  -3151.42 -9322.89  -748.09 -58324.19
# 1   2  14649.96  38475.91 -111926.11 -11979.66 -6929.85  1294.46 -56696.81
# 2   3   9922.77  30354.99 -121728.38 -22306.95 -4714.03  3366.64 -54822.73
#
#          8    9    10   11             12
# 0 -21247.52  0.0  0.0  0.0   06:41:04.314
# 1 -22616.95  0.0  0.0  0.0   06:41:04.314
# 2 -23055.42  0.0  0.0  0.0   06:41:04.314

# %%
d_plot(n_no_bp_no)
